# %%
import pandas as pd
import numpy as np
import copy
import os
from tqdm import tqdm
import json

# %%
import matplotlib.pyplot as plt

# %%
from pandarallel import pandarallel

pandarallel.initialize(progress_bar=False)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# ## For case studies

# %%
benchmark_directory = "/projects/mcmm/results_final/"

# %%
def get_info_from_filename(np_fname):
    splitted = np_fname.lower().split("_")
    func = splitted[0]
    dim = int(splitted[1])
    
    algorithm = None
    if "basinhopping" in np_fname:
        assert algorithm is None; algorithm = "basinhopping"
    elif "differential_evolution" in np_fname:
        assert algorithm is None; algorithm = "differential_evolution"
    elif "direct" in np_fname:
        assert algorithm is None; algorithm = "direct"
    elif "dual_annealing" in np_fname:
        assert algorithm is None; algorithm = "dual_annealing"
    elif "shgo" in np_fname:
        assert algorithm is None; algorithm = "shgo"
    elif "simulated_annealing" in np_fname:
        assert algorithm is None; algorithm = "simulated_annealing"
    elif "mcir" in np_fname:
        assert algorithm is None; algorithm = "mcir"
    
    assert algorithm is not None, "algorithm not found in {}".format(np_fname)
    
    info = {
        "function": func,
        "dimension": dim,
        "algorithm": algorithm,
    }
    return info

# %%
all_results = []
already_run_file_prefix = []

for filename in os.listdir(benchmark_directory):
    if not filename.endswith("_Y.npy"):
        print("Skipping {}".format(filename))
        continue

    result_dict = get_info_from_filename(filename)
    result_dict['obj_list'] = np.load(os.path.join(benchmark_directory, filename))
    
    already_run_file_prefix.append(filename[:-6])
    
    stats_filename = filename[:-6] + ".json"
    stats_filepath = os.path.join(benchmark_directory, "stats", stats_filename)
    
    if os.path.exists(stats_filepath):
        with open(stats_filepath) as f:
            stats = json.load(f)

        result_dict['total_time'] = stats['time_elapsed']
        result_dict['timeout_reached'] = stats['timeout_reached']
    else:
        result_dict['total_time'] = -1
        result_dict['timeout_reached'] = None
    
    all_results.append(result_dict)
# Out:
# Skipping stats

# %%
# Process gurobi runs
for filename in os.listdir(os.path.join(benchmark_directory, "stats")):
    if not filename.endswith(".json"):
        print("Skipping {}".format(filename))
        continue
    
    if 'gurobi' in filename:
        print("Processing {}".format(filename))
        
        func = filename.lower().split("_")[0]
        dim = int(filename.lower().split("_")[1])
        algorithm = filename.lower().split("_")[2]
        
        with open(os.path.join(benchmark_directory, "stats", filename)) as f:
            stats = json.load(f)
        
        result_dict = {
            "function": func,
            "dimension": dim,
            "algorithm": algorithm,
            "obj_list": [stats['obj_val']],
            "total_time": stats['time_elapsed'],
            "timeout_reached": None,
        }
        
        all_results.append(result_dict)
# Out:
# Processing Levy_200_gurobi_4.json
# Processing Michalewicz_200_gurobi_4.json
# Processing Ackley_50_gurobi_1.json
# Processing Levy_100_gurobi_0.json
# Processing Michalewicz_100_gurobi_3.json
# Processing Levy_200_gurobi_3.json
# Processing Michalewicz_100_gurobi_0.json
# Processing Ackley_200_gurobi_2.json
# Processing Levy_200_gurobi_2.json
# Processing Michalewicz_200_gurobi_2.json
# Processing Ackley_100_gurobi_2.json
# Processing Ackley_100_gurobi_1.json
# Processing Michalewicz_100_gurobi_4.json
# Processing Michalewicz_200_gurobi_3.json
# Processing Michalewicz_10_gurobi_0.json
# Processing Levy_100_gurobi_3.json
# Processing Michalewicz_200_gurobi_1.json
# Processing Michalewicz_10_gurobi_1.json
# Processing Ackley_100_gurobi_0.json
# Processing Ackley_10_gurobi_2.json
# Processing Ackley_50_gurobi_0.json
# Processing Levy_100_gurobi_1.json
# Processing Michalewicz_50_gurobi_4.json
# Processing Levy_100_gurobi_2.json
# Processing Michalewicz_10_gurobi_3.json
# Processing Ackley_10_gurobi_1.json
# Processing Levy_200_gurobi_0.json
# Processing Ackley_50_gurobi_4.json
# Processing Michalewicz_100_gurobi_2.json
# Processing Michalewicz_10_gurobi_4.json
# Processing Ackley_10_gurobi_0.json
# Processing Ackley_200_gurobi_3.json
# Processing Ackley_200_gurobi_4.json
# Processing Levy_100_gurobi_4.json
# Processing Michalewicz_10_gurobi_2.json
# Processing Ackley_10_gurobi_3.json
# Processing Ackley_50_gurobi_2.json
# Processing Ackley_200_gurobi_0.json
# Processing Michalewicz_50_gurobi_0.json
# Processing Ackley_200_gurobi_1.json
# Processing Ackley_10_gurobi_4.json
# Processing Ackley_100_gurobi_3.json
# Processing Ackley_50_gurobi_3.json
# Processing Michalewicz_50_gurobi_2.json
# Processing Michalewicz_50_gurobi_3.json
# Processing Levy_200_gurobi_1.json
# Processing Michalewicz_50_gurobi_1.json
# Processing Ackley_100_gurobi_4.json
# Processing Michalewicz_200_gurobi_0.json
# Processing Michalewicz_100_gurobi_1.json

# %%
def find_first_reach_sample(nums):
    first_reach_sample = len(nums)
    best_sample_val = float('inf')
    for idx, val in enumerate(nums):
        if val < best_sample_val:
            best_sample_val = val
            first_reach_sample = idx
    
    return (best_sample_val, first_reach_sample)

# %%
result_df = pd.DataFrame(all_results)
result_df
# Out:
#         function  dimension     algorithm
# 0      nn-ackley         50  basinhopping  \
# 1         ackley         50  basinhopping
# 2           levy         50          mcir
# 3        harkerp        101          mcir
# 4    michalewicz        200          mcir
# ..           ...        ...           ...
# 681         levy        200        gurobi
# 682  michalewicz         50        gurobi
# 683       ackley        100        gurobi
# 684  michalewicz        200        gurobi
# 685  michalewicz        100        gurobi
#
#                                               obj_list  total_time
# 0    [21.189709, 21.189709, 21.189709, 21.189709, 2...  108.239230  \
# 1    [20.977924, 20.977924, 20.977924, 20.977924, 2...    5.943726
# 2    [479.7550964355469, 479.7550964355469, 479.755...   -1.000000
# 3    [12967036.0, 12967036.0, 12967036.0, 248121.71...   -1.000000
# 4    [-23.66192054748535, -23.66192054748535, -23.6...   -1.000000
# ..                                                 ...         ...
# 681                            [-0.000163713388551661]   24.009706
# 682                               [-49.85208419858109]    4.966436
# 683                                [2.021709219484489]    0.156366
# 684                              [-202.46349824889242]   26.289410
# 685                              [-100.54147783848003]   12.716558
#
#     timeout_reached
# 0             False
# 1             False
# 2              None
# 3              None
# 4              None
# ..              ...
# 681            None
# 682            None
# 683            None
# 684            None
# 685            None
#
# [686 rows x 6 columns]

# %%
result_df['obj_stat'] = result_df['obj_list'].parallel_apply(find_first_reach_sample)

# %%
result_df['best_y'] = result_df['obj_stat'].apply(lambda x: x[0])
result_df['first_reach_sample'] = result_df['obj_stat'].apply(lambda x: x[1])
result_df['total_sample'] = result_df['obj_list'].parallel_apply(len)

# %%
result_df = result_df.drop(['obj_list', 'obj_stat'], axis=1)

# %%
result_df = result_df.sort_values(["function", "dimension", "algorithm", "best_y", "first_reach_sample", "total_time"])

# %%
result_df = result_df[[
    'function', 'dimension', 'algorithm', 'best_y', 'total_time', 
    'total_sample', 'first_reach_sample', 'timeout_reached']]

# %%
result_df.to_pickle("appen_raw_results.pkl")
result_df
# Out:
#     function  dimension     algorithm     best_y   total_time  total_sample
# 351   ackley         10  basinhopping  19.079865     1.612064         11517  \
# 59    ackley         10  basinhopping  19.804897     1.954477         11363
# 436   ackley         10  basinhopping  19.835838     1.707414         11440
# 339   ackley         10  basinhopping  20.304733     1.725310         11407
# 105   ackley         10  basinhopping  20.540028     1.602051         11671
# ..       ...        ...           ...        ...          ...           ...
# 54    watson         32          shgo        inf  3601.669902             0
# 288   watson         32          shgo        inf  3601.854003             0
# 148   watson         32          shgo        inf  3601.968753             0
# 559   watson         32          shgo        inf  3601.974911             0
# 222   watson         32          shgo        inf  3602.063887             0
#
#      first_reach_sample timeout_reached
# 351                5159           False
# 59                 5929           False
# 436                4224           False
# 339                1243           False
# 105                8294           False
# ..                  ...             ...
# 54                    0            True
# 288                   0            True
# 148                   0            True
# 559                   0            True
# 222                   0            True
#
# [686 rows x 8 columns]

# %%
result_df[result_df['algorithm'] != 'mcir'].to_csv('results_no_mcir.csv', index=False)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
result_df
# Out:
#            function  dimension               algorithm        best_y
# 351          ackley         10            basinhopping  1.907986e+01  \
# 59           ackley         10            basinhopping  1.980490e+01
# 436          ackley         10            basinhopping  1.983584e+01
# 339          ackley         10            basinhopping  2.030473e+01
# 105          ackley         10            basinhopping  2.054003e+01
# 591          ackley         10  differential_evolution  9.536743e-07
# 268          ackley         10  differential_evolution  9.536743e-07
# 182          ackley         10  differential_evolution  9.536743e-07
# 410          ackley         10  differential_evolution  9.536743e-07
# 404          ackley         10  differential_evolution  9.536743e-07
# 371          ackley         10                  direct  3.867398e+00
# 343          ackley         10                  direct  3.867398e+00
# 403          ackley         10                  direct  3.867398e+00
# 394          ackley         10                  direct  3.867398e+00
# 281          ackley         10                  direct  3.867398e+00
# 377          ackley         10          dual_annealing  3.805161e-04
# 270          ackley         10          dual_annealing  4.644394e-04
# 10           ackley         10          dual_annealing  6.093979e-04
# 594          ackley         10          dual_annealing  6.189346e-04
# 216          ackley         10          dual_annealing  6.608963e-04
# 666          ackley         10                  gurobi  2.021709e+00
# 661          ackley         10                  gurobi  2.021709e+00
# 655          ackley         10                  gurobi  2.021709e+00
# 676          ackley         10                  gurobi  2.021709e+00
# 671          ackley         10                  gurobi  2.021709e+00
# 51           ackley         10                    mcir  9.536743e-07
# 100          ackley         10                    mcir  9.536743e-07
# 380          ackley         10                    mcir  9.536743e-07
# 423          ackley         10                    mcir  1.155149e+00
# 65           ackley         10                    mcir  1.646222e+00
# 415          ackley         10                    shgo           inf
# 399          ackley         10                    shgo           inf
# 331          ackley         10                    shgo           inf
# 416          ackley         10                    shgo           inf
# 125          ackley         10                    shgo           inf
# 299          ackley         10     simulated_annealing  2.756119e-04
# 76           ackley         10     simulated_annealing  3.519058e-04
# 160          ackley         10     simulated_annealing  4.091263e-04
# 169          ackley         10     simulated_annealing  4.739761e-04
# 509          ackley         10     simulated_annealing  5.197525e-04
# 289          ackley         50            basinhopping  2.049384e+01
# 1            ackley         50            basinhopping  2.079861e+01
# 467          ackley         50            basinhopping  2.084268e+01
# 391          ackley         50            basinhopping  2.096784e+01
# 596          ackley         50            basinhopping  2.107606e+01
# 309          ackley         50  differential_evolution  1.984366e+01
# 176          ackley         50  differential_evolution  2.004780e+01
# 184          ackley         50  differential_evolution  2.026557e+01
# 116          ackley         50  differential_evolution  2.033181e+01
# 601          ackley         50  differential_evolution  2.043919e+01
# 96           ackley         50                  direct  4.552539e+00
# 592          ackley         50                  direct  4.552539e+00
# 572          ackley         50                  direct  4.552539e+00
# 188          ackley         50                  direct  4.552539e+00
# 42           ackley         50                  direct  4.552539e+00
# 554          ackley         50          dual_annealing  9.164810e-04
# 430          ackley         50          dual_annealing  9.717941e-04
# 496          ackley         50          dual_annealing  1.196861e-03
# 264          ackley         50          dual_annealing  1.221657e-03
# 279          ackley         50          dual_annealing  1.288414e-03
# 663          ackley         50                  gurobi  2.021709e+00
# 638          ackley         50                  gurobi  2.021709e+00
# 672          ackley         50                  gurobi  2.021709e+00
# 678          ackley         50                  gurobi  2.021709e+00
# 656          ackley         50                  gurobi  2.021709e+00
# 313          ackley         50                    mcir -9.536743e-07
# 464          ackley         50                    mcir -9.536743e-07
# 265          ackley         50                    mcir -9.536743e-07
# 551          ackley         50                    mcir  1.561280e+00
# 219          ackley         50                    mcir  1.561282e+00
# 137          ackley         50                    shgo           inf
# 48           ackley         50                    shgo           inf
# 329          ackley         50                    shgo           inf
# 602          ackley         50                    shgo           inf
# 583          ackley         50                    shgo           inf
# 392          ackley         50     simulated_annealing  9.412766e-04
# 302          ackley         50     simulated_annealing  1.076698e-03
# 462          ackley         50     simulated_annealing  1.084328e-03
# 547          ackley         50     simulated_annealing  1.206398e-03
# 252          ackley         50     simulated_annealing  1.240730e-03
# 157          ackley        100            basinhopping  2.081739e+01
# 604          ackley        100            basinhopping  2.094283e+01
# 32           ackley        100            basinhopping  2.094855e+01
# 189          ackley        100            basinhopping  2.108840e+01
# 357          ackley        100            basinhopping  2.110433e+01
# 340          ackley        100  differential_evolution  2.057652e+01
# 346          ackley        100  differential_evolution  2.064194e+01
# 45           ackley        100  differential_evolution  2.067028e+01
# 603          ackley        100  differential_evolution  2.068922e+01
# 609          ackley        100  differential_evolution  2.074972e+01
# 180          ackley        100                  direct  4.552539e+00
# 567          ackley        100                  direct  4.552539e+00
# 512          ackley        100                  direct  4.552539e+00
# 319          ackley        100                  direct  4.552539e+00
# 565          ackley        100                  direct  4.552539e+00
# 75           ackley        100          dual_annealing  1.843452e-03
# 353          ackley        100          dual_annealing  2.049446e-03
# 151          ackley        100          dual_annealing  2.150536e-03
# 34           ackley        100          dual_annealing  2.263069e-03
# 450          ackley        100          dual_annealing  2.270699e-03
# 646          ackley        100                  gurobi  2.021709e+00
# 654          ackley        100                  gurobi  2.021709e+00
# 683          ackley        100                  gurobi  2.021709e+00
# 677          ackley        100                  gurobi  2.021709e+00
# 647          ackley        100                  gurobi  2.021709e+00
# 445          ackley        100                    mcir  0.000000e+00
# 524          ackley        100                    mcir  0.000000e+00
# 27           ackley        100                    mcir  0.000000e+00
# 227          ackley        100                    mcir  0.000000e+00
# 74           ackley        100                    mcir  0.000000e+00
# 354          ackley        100                    mcir  0.000000e+00
# 209          ackley        100                    mcir  0.000000e+00
# 517          ackley        100                    mcir  0.000000e+00
# 235          ackley        100                    mcir  0.000000e+00
# 284          ackley        100                    mcir  0.000000e+00
# 13           ackley        100                    shgo           inf
# 624          ackley        100                    shgo           inf
# 498          ackley        100                    shgo           inf
# 83           ackley        100                    shgo           inf
# 256          ackley        100                    shgo           inf
# 595          ackley        100     simulated_annealing  1.973152e-03
# 294          ackley        100     simulated_annealing  1.994133e-03
# 376          ackley        100     simulated_annealing  2.081871e-03
# 144          ackley        100     simulated_annealing  2.299309e-03
# 123          ackley        100     simulated_annealing  2.324104e-03
# 203          ackley        200            basinhopping  2.108415e+01
# 474          ackley        200            basinhopping  2.108833e+01
# 98           ackley        200            basinhopping  2.110282e+01
# 379          ackley        200            basinhopping  2.112611e+01
# 126          ackley        200            basinhopping  2.127156e+01
# 530          ackley        200  differential_evolution  2.044463e+01
# 409          ackley        200  differential_evolution  2.059386e+01
# 316          ackley        200  differential_evolution  2.060509e+01
# 211          ackley        200  differential_evolution  2.072615e+01
# 303          ackley        200  differential_evolution  2.079733e+01
# 127          ackley        200                  direct  4.552539e+00
# 107          ackley        200                  direct  4.552539e+00
# 183          ackley        200                  direct  4.552539e+00
# 73           ackley        200                  direct  4.552539e+00
# 195          ackley        200                  direct  4.552539e+00
# 570          ackley        200          dual_annealing  4.012108e-03
# 519          ackley        200          dual_annealing  4.038811e-03
# 614          ackley        200          dual_annealing  4.099846e-03
# 374          ackley        200          dual_annealing  4.145622e-03
# 378          ackley        200          dual_annealing  4.250526e-03
# 668          ackley        200                  gurobi  2.021709e+00
# 675          ackley        200                  gurobi  2.021709e+00
# 673          ackley        200                  gurobi  2.021709e+00
# 643          ackley        200                  gurobi  2.021709e+00
# 667          ackley        200                  gurobi  2.021709e+00
# 164          ackley        200                    mcir  0.000000e+00
# 296          ackley        200                    mcir  0.000000e+00
# 362          ackley        200                    mcir  0.000000e+00
# 492          ackley        200                    mcir  0.000000e+00
# 226          ackley        200                    mcir  0.000000e+00
# 501          ackley        200                    mcir  0.000000e+00
# 152          ackley        200                    mcir  0.000000e+00
# 156          ackley        200                    mcir  0.000000e+00
# 38           ackley        200                    mcir  2.567408e+00
# 556          ackley        200                    mcir  2.567408e+00
# 207          ackley        200                    shgo           inf
# 627          ackley        200                    shgo           inf
# 576          ackley        200                    shgo           inf
# 579          ackley        200                    shgo           inf
# 242          ackley        200                    shgo           inf
# 174          ackley        200     simulated_annealing  3.598213e-03
# 82           ackley        200     simulated_annealing  3.699303e-03
# 185          ackley        200     simulated_annealing  4.113197e-03
# 460          ackley        200     simulated_annealing  4.218102e-03
# 459          ackley        200     simulated_annealing  4.620552e-03
# 381        biggsbi1       1001  differential_evolution  4.983909e+01
# 5          biggsbi1       1001  differential_evolution  5.504335e+01
# 333        biggsbi1       1001  differential_evolution  5.657994e+01
# 393        biggsbi1       1001  differential_evolution  5.768036e+01
# 514        biggsbi1       1001  differential_evolution  6.170566e+01
# 546        biggsbi1       1001                  direct  1.659200e+00
# 465        biggsbi1       1001                  direct  1.659200e+00
# 307        biggsbi1       1001                  direct  1.659200e+00
# 124        biggsbi1       1001                  direct  1.659200e+00
# 249        biggsbi1       1001                  direct  1.659200e+00
# 86         biggsbi1       1001          dual_annealing  5.397040e+00
# 248        biggsbi1       1001          dual_annealing  5.516618e+00
# 550        biggsbi1       1001          dual_annealing  1.175508e+01
# 478        biggsbi1       1001                    mcir  2.086540e-02
# 523        eigenals        111                    mcir  4.121255e-06
# 555         harkerp        101            basinhopping -4.999732e+01
# 487         harkerp        101            basinhopping -4.999231e+01
# 503         harkerp        101            basinhopping -4.998975e+01
# 370         harkerp        101            basinhopping -4.998725e+01
# 112         harkerp        101            basinhopping -4.996675e+01
# 600         harkerp        101  differential_evolution -8.919054e-01
# 230         harkerp        101  differential_evolution -8.276868e-01
# 250         harkerp        101  differential_evolution -7.859808e-01
# 133         harkerp        101  differential_evolution -7.704592e-01
# 241         harkerp        101  differential_evolution -6.673853e-01
# 139         harkerp        101                  direct  5.266896e+06
# 140         harkerp        101                  direct  5.266896e+06
# 437         harkerp        101                  direct  5.266896e+06
# 628         harkerp        101                  direct  5.266896e+06
# 607         harkerp        101                  direct  5.266896e+06
# 20          harkerp        101          dual_annealing -8.653091e-01
# 447         harkerp        101          dual_annealing -7.410843e-01
# 443         harkerp        101          dual_annealing -7.224104e-01
# 562         harkerp        101          dual_annealing -5.615546e-01
# 121         harkerp        101          dual_annealing -5.251550e-01
# 3           harkerp        101                    mcir -9.275848e-01
# 49          harkerp        101                    mcir -9.275848e-01
# 549         harkerp        101                    shgo           inf
# 330         harkerp        101                    shgo           inf
# 322         harkerp        101                    shgo           inf
# 300         harkerp        101                    shgo           inf
# 218         harkerp        101                    shgo           inf
# 635            levy         10            basinhopping  6.419000e+00
# 92             levy         10            basinhopping  1.334873e+01
# 421            levy         10            basinhopping  2.392315e+01
# 520            levy         10            basinhopping  2.447446e+01
# 400            levy         10            basinhopping  3.390902e+01
# 215            levy         10  differential_evolution  7.667634e-15
# 274            levy         10  differential_evolution  7.668323e-15
# 247            levy         10  differential_evolution  7.676852e-15
# 528            levy         10  differential_evolution  7.683767e-15
# 304            levy         10  differential_evolution  7.692546e-15
# 89             levy         10                  direct  7.744227e-02
# 317            levy         10                  direct  7.744227e-02
# 617            levy         10                  direct  7.744227e-02
# 103            levy         10                  direct  7.744227e-02
# 491            levy         10                  direct  7.744227e-02
# 162            levy         10          dual_annealing  2.186424e-12
# 217            levy         10          dual_annealing  4.060618e-11
# 141            levy         10          dual_annealing  5.679497e-11
# 405            levy         10          dual_annealing  3.076858e-10
# 87             levy         10          dual_annealing  9.089359e-10
# 365            levy         10                    mcir  8.507693e-13
# 198            levy         10                    mcir  9.941667e-13
# 192            levy         10                    mcir  1.600410e-12
# 179            levy         10                    mcir  3.858173e-12
# 382            levy         10                    mcir  4.188216e-12
# 384            levy         10                    shgo           inf
# 30             levy         10                    shgo           inf
# 511            levy         10                    shgo           inf
# 489            levy         10                    shgo           inf
# 545            levy         10                    shgo           inf
# 193            levy         10     simulated_annealing  3.280966e-05
# 433            levy         10     simulated_annealing  3.941192e-05
# 122            levy         10     simulated_annealing  4.338363e-05
# 337            levy         10     simulated_annealing  4.975309e-05
# 347            levy         10     simulated_annealing  5.157519e-05
# 283            levy         50            basinhopping  8.888474e+01
# 342            levy         50            basinhopping  1.050860e+02
# 271            levy         50            basinhopping  1.097022e+02
# 213            levy         50            basinhopping  1.283545e+02
# 52             levy         50            basinhopping  1.429448e+02
# 468            levy         50  differential_evolution  7.859549e-15
# 388            levy         50  differential_evolution  5.953669e-14
# 493            levy         50  differential_evolution  9.198270e-02
# 261            levy         50  differential_evolution  1.253547e-01
# 58             levy         50  differential_evolution  4.693419e-01
# 33             levy         50                  direct  1.377587e+01
# 397            levy         50                  direct  1.377587e+01
# 349            levy         50                  direct  1.377587e+01
# 621            levy         50                  direct  1.377587e+01
# 62             levy         50                  direct  1.377587e+01
# 79             levy         50          dual_annealing  2.238545e-11
# 145            levy         50          dual_annealing  2.346539e-10
# 143            levy         50          dual_annealing  5.315187e-10
# 277            levy         50          dual_annealing  7.657684e-10
# 273            levy         50          dual_annealing  3.207061e-09
# 449            levy         50                    mcir  2.705896e+00
# 2              levy         50                    mcir  4.626808e+00
# 260            levy         50                    mcir  5.474019e+00
# 356            levy         50                    mcir  6.689942e+00
# 581            levy         50                    mcir  8.447785e+00
# 396            levy         50                    shgo           inf
# 37             levy         50                    shgo           inf
# 99             levy         50                    shgo           inf
# 44             levy         50                    shgo           inf
# 417            levy         50                    shgo           inf
# 615            levy         50     simulated_annealing  3.661927e-04
# 386            levy         50     simulated_annealing  3.915962e-04
# 348            levy         50     simulated_annealing  3.956441e-04
# 336            levy         50     simulated_annealing  4.041702e-04
# 318            levy         50     simulated_annealing  4.157778e-04
# 355            levy        100            basinhopping  2.098738e+02
# 432            levy        100            basinhopping  2.224530e+02
# 130            levy        100            basinhopping  2.386179e+02
# 448            levy        100            basinhopping  2.804336e+02
# 228            levy        100            basinhopping  2.933190e+02
# 108            levy        100  differential_evolution  2.263348e+00
# 205            levy        100  differential_evolution  2.856406e+00
# 500            levy        100  differential_evolution  2.958713e+00
# 119            levy        100  differential_evolution  3.520793e+00
# 557            levy        100  differential_evolution  4.238809e+00
# 508            levy        100                  direct  2.741188e+01
# 287            levy        100                  direct  2.741188e+01
# 569            levy        100                  direct  2.741188e+01
# 234            levy        100                  direct  2.741188e+01
# 101            levy        100                  direct  2.741188e+01
# 359            levy        100          dual_annealing  5.779855e-11
# 323            levy        100          dual_annealing  9.029265e-11
# 599            levy        100          dual_annealing  1.035547e-10
# 224            levy        100          dual_annealing  2.506797e-09
# 516            levy        100          dual_annealing  4.961315e-04
# 639            levy        100                  gurobi -8.870064e-07
# 651            levy        100                  gurobi -8.870064e-07
# 657            levy        100                  gurobi -8.870064e-07
# 669            levy        100                  gurobi -8.870064e-07
# 659            levy        100                  gurobi -8.870064e-07
# 154            levy        100                    mcir  7.607248e+00
# 311            levy        100                    mcir  7.607248e+00
# 91             levy        100                    mcir  8.133319e+00
# 402            levy        100                    mcir  8.133319e+00
# 324            levy        100                    mcir  8.889814e+00
# 456            levy        100                    mcir  8.889814e+00
# 419            levy        100                    mcir  9.758154e+00
# 548            levy        100                    mcir  9.758154e+00
# 360            levy        100                    mcir  1.159650e+01
# 422            levy        100                    mcir  1.159650e+01
# 368            levy        100                    shgo           inf
# 204            levy        100                    shgo           inf
# 244            levy        100                    shgo           inf
# 165            levy        100                    shgo           inf
# 525            levy        100                    shgo           inf
# 575            levy        100     simulated_annealing  7.643627e-04
# 43             levy        100     simulated_annealing  8.128848e-04
# 439            levy        100     simulated_annealing  8.705931e-04
# 147            levy        100     simulated_annealing  9.145476e-04
# 15             levy        100     simulated_annealing  1.014467e-03
# 455            levy        200            basinhopping  5.833246e+02
# 134            levy        200            basinhopping  6.555451e+02
# 375            levy        200            basinhopping  6.596384e+02
# 553            levy        200            basinhopping  6.610395e+02
# 259            levy        200            basinhopping  7.450388e+02
# 308            levy        200  differential_evolution  1.617637e+01
# 494            levy        200  differential_evolution  2.142602e+01
# 50             levy        200  differential_evolution  2.293953e+01
# 286            levy        200  differential_evolution  2.640784e+01
# 14             levy        200  differential_evolution  3.101587e+01
# 135            levy        200                  direct  5.468391e+01
# 608            levy        200                  direct  5.468391e+01
# 325            levy        200                  direct  5.468391e+01
# 532            levy        200                  direct  5.468391e+01
# 630            levy        200                  direct  5.468391e+01
# 70             levy        200          dual_annealing  3.886011e-10
# 527            levy        200          dual_annealing  1.032762e-09
# 155            levy        200          dual_annealing  5.030460e-04
# 46             levy        200          dual_annealing  7.213206e-04
# 187            levy        200          dual_annealing  1.193034e-03
# 644            levy        200                  gurobi -1.637134e-04
# 662            levy        200                  gurobi -1.637134e-04
# 636            levy        200                  gurobi -1.637134e-04
# 641            levy        200                  gurobi -1.637134e-04
# 681            levy        200                  gurobi -1.637134e-04
# 80             levy        200                    mcir  1.593737e+01
# 620            levy        200                    mcir  1.593737e+01
# 40             levy        200                    mcir  1.814618e+01
# 590            levy        200                    mcir  1.814618e+01
# 24             levy        200                    mcir  1.967485e+01
# 315            levy        200                    mcir  1.967485e+01
# 223            levy        200                    mcir  2.077839e+01
# 389            levy        200                    mcir  2.077839e+01
# 16             levy        200                    mcir  2.815286e+01
# 276            levy        200                    mcir  2.815286e+01
# 414            levy        200                    shgo           inf
# 161            levy        200                    shgo           inf
# 425            levy        200                    shgo           inf
# 426            levy        200                    shgo           inf
# 177            levy        200                    shgo           inf
# 191            levy        200     simulated_annealing  1.562043e-03
# 373            levy        200     simulated_annealing  1.704743e-03
# 473            levy        200     simulated_annealing  1.804096e-03
# 64             levy        200     simulated_annealing  1.816341e-03
# 558            levy        200     simulated_annealing  1.887839e-03
# 233     michalewicz         10            basinhopping -3.833464e+00
# 272     michalewicz         10            basinhopping -3.552388e+00
# 542     michalewicz         10            basinhopping -3.389693e+00
# 535     michalewicz         10            basinhopping -3.382529e+00
# 310     michalewicz         10            basinhopping -3.104609e+00
# 11      michalewicz         10  differential_evolution -9.585487e+00
# 598     michalewicz         10  differential_evolution -9.549730e+00
# 561     michalewicz         10  differential_evolution -9.414070e+00
# 178     michalewicz         10  differential_evolution -9.385286e+00
# 68      michalewicz         10  differential_evolution -9.312387e+00
# 275     michalewicz         10                  direct -8.199029e+00
# 60      michalewicz         10                  direct -8.199029e+00
# 36      michalewicz         10                  direct -8.199029e+00
# 93      michalewicz         10                  direct -8.199029e+00
# 481     michalewicz         10                  direct -8.199029e+00
# 23      michalewicz         10          dual_annealing -9.660105e+00
# 522     michalewicz         10          dual_annealing -9.660081e+00
# 254     michalewicz         10          dual_annealing -9.660055e+00
# 21      michalewicz         10          dual_annealing -9.660043e+00
# 29      michalewicz         10          dual_annealing -9.655106e+00
# 670     michalewicz         10                  gurobi -9.714386e+00
# 653     michalewicz         10                  gurobi -9.714386e+00
# 665     michalewicz         10                  gurobi -9.714386e+00
# 650     michalewicz         10                  gurobi -9.714386e+00
# 660     michalewicz         10                  gurobi -9.714386e+00
# 18      michalewicz         10                    mcir -9.048040e+00
# 534     michalewicz         10                    mcir -9.043833e+00
# 469     michalewicz         10                    mcir -8.756279e+00
# 446     michalewicz         10                    mcir -8.679165e+00
# 611     michalewicz         10                    mcir -8.581614e+00
# 282     michalewicz         10                    mcir -8.575459e+00
# 210     michalewicz         10                    mcir -8.497469e+00
# 26      michalewicz         10                    mcir -8.347014e+00
# 117     michalewicz         10                    mcir -8.329524e+00
# 345     michalewicz         10                    mcir -8.210482e+00
# 171     michalewicz         10                    mcir -7.996818e+00
# 442     michalewicz         10                    shgo           inf
# 6       michalewicz         10                    shgo           inf
# 306     michalewicz         10                    shgo           inf
# 231     michalewicz         10                    shgo           inf
# 290     michalewicz         10                    shgo           inf
# 229     michalewicz         10     simulated_annealing -9.660122e+00
# 168     michalewicz         10     simulated_annealing -9.660044e+00
# 407     michalewicz         10     simulated_annealing -9.660038e+00
# 115     michalewicz         10     simulated_annealing -9.660036e+00
# 495     michalewicz         10     simulated_annealing -9.659973e+00
# 301     michalewicz         50            basinhopping -1.007855e+01
# 566     michalewicz         50            basinhopping -9.096802e+00
# 7       michalewicz         50            basinhopping -8.860116e+00
# 584     michalewicz         50            basinhopping -8.680302e+00
# 240     michalewicz         50            basinhopping -7.500476e+00
# 47      michalewicz         50  differential_evolution -2.213320e+01
# 440     michalewicz         50  differential_evolution -2.014066e+01
# 263     michalewicz         50  differential_evolution -1.995487e+01
# 387     michalewicz         50  differential_evolution -1.950597e+01
# 28      michalewicz         50  differential_evolution -1.921848e+01
# 538     michalewicz         50                  direct -1.308269e+01
# 77      michalewicz         50                  direct -1.308269e+01
# 257     michalewicz         50                  direct -1.308269e+01
# 314     michalewicz         50                  direct -1.308269e+01
# 618     michalewicz         50                  direct -1.308269e+01
# 466     michalewicz         50          dual_annealing -4.956044e+01
# 539     michalewicz         50          dual_annealing -4.955405e+01
# 212     michalewicz         50          dual_annealing -4.954047e+01
# 586     michalewicz         50          dual_annealing -4.952995e+01
# 585     michalewicz         50          dual_annealing -4.952553e+01
# 680     michalewicz         50                  gurobi -4.985208e+01
# 658     michalewicz         50                  gurobi -4.985208e+01
# 674     michalewicz         50                  gurobi -4.985208e+01
# 682     michalewicz         50                  gurobi -4.985208e+01
# 679     michalewicz         50                  gurobi -4.985208e+01
# 588     michalewicz         50                    mcir -4.880784e+01
# 513     michalewicz         50                    mcir -4.857901e+01
# 629     michalewicz         50                    mcir -4.855149e+01
# 208     michalewicz         50                    mcir -4.729021e+01
# 418     michalewicz         50                    mcir -4.698301e+01
# 543     michalewicz         50                    shgo           inf
# 320     michalewicz         50                    shgo           inf
# 292     michalewicz         50                    shgo           inf
# 55      michalewicz         50                    shgo           inf
# 597     michalewicz         50                    shgo           inf
# 245     michalewicz         50     simulated_annealing -4.954107e+01
# 12      michalewicz         50     simulated_annealing -4.952932e+01
# 97      michalewicz         50     simulated_annealing -4.952799e+01
# 480     michalewicz         50     simulated_annealing -4.950182e+01
# 120     michalewicz         50     simulated_annealing -4.950147e+01
# 225     michalewicz        100            basinhopping -1.540055e+01
# 350     michalewicz        100            basinhopping -1.502887e+01
# 63      michalewicz        100            basinhopping -1.488009e+01
# 31      michalewicz        100            basinhopping -1.452945e+01
# 632     michalewicz        100            basinhopping -1.363375e+01
# 167     michalewicz        100  differential_evolution -3.138671e+01
# 298     michalewicz        100  differential_evolution -3.113481e+01
# 457     michalewicz        100  differential_evolution -3.109941e+01
# 390     michalewicz        100  differential_evolution -2.977824e+01
# 606     michalewicz        100  differential_evolution -2.961772e+01
# 267     michalewicz        100                  direct -2.614982e+01
# 335     michalewicz        100                  direct -2.614982e+01
# 278     michalewicz        100                  direct -2.614982e+01
# 444     michalewicz        100                  direct -2.614982e+01
# 383     michalewicz        100                  direct -2.614982e+01
# 305     michalewicz        100          dual_annealing -9.943712e+01
# 502     michalewicz        100          dual_annealing -9.943453e+01
# 132     michalewicz        100          dual_annealing -9.943176e+01
# 463     michalewicz        100          dual_annealing -9.942951e+01
# 619     michalewicz        100          dual_annealing -9.938194e+01
# 664     michalewicz        100                  gurobi -1.005415e+02
# 640     michalewicz        100                  gurobi -1.005415e+02
# 642     michalewicz        100                  gurobi -1.005415e+02
# 685     michalewicz        100                  gurobi -1.005415e+02
# 648     michalewicz        100                  gurobi -1.005415e+02
# 366     michalewicz        100                    mcir -9.336638e+01
# 506     michalewicz        100                    mcir -9.336638e+01
# 476     michalewicz        100                    mcir -9.297594e+01
# 526     michalewicz        100                    mcir -9.297594e+01
# 435     michalewicz        100                    mcir -9.154474e+01
# 475     michalewicz        100                    mcir -9.154474e+01
# 17      michalewicz        100                    mcir -9.107086e+01
# 53      michalewicz        100                    mcir -9.107086e+01
# 71      michalewicz        100                    mcir -9.067631e+01
# 536     michalewicz        100                    mcir -9.067631e+01
# 41      michalewicz        100                    shgo           inf
# 518     michalewicz        100                    shgo           inf
# 334     michalewicz        100                    shgo           inf
# 69      michalewicz        100                    shgo           inf
# 90      michalewicz        100                    shgo           inf
# 533     michalewicz        100     simulated_annealing -9.947768e+01
# 239     michalewicz        100     simulated_annealing -9.942706e+01
# 297     michalewicz        100     simulated_annealing -9.940269e+01
# 149     michalewicz        100     simulated_annealing -9.940079e+01
# 258     michalewicz        100     simulated_annealing -9.938030e+01
# 206     michalewicz        200            basinhopping -2.999989e+01
# 626     michalewicz        200            basinhopping -2.760143e+01
# 587     michalewicz        200            basinhopping -2.717377e+01
# 358     michalewicz        200            basinhopping -2.705708e+01
# 236     michalewicz        200            basinhopping -2.467911e+01
# 237     michalewicz        200  differential_evolution -5.128458e+01
# 486     michalewicz        200  differential_evolution -5.026558e+01
# 232     michalewicz        200  differential_evolution -4.786552e+01
# 136     michalewicz        200  differential_evolution -4.731038e+01
# 312     michalewicz        200  differential_evolution -4.552489e+01
# 427     michalewicz        200                  direct -5.114774e+01
# 173     michalewicz        200                  direct -5.114774e+01
# 25      michalewicz        200                  direct -5.114774e+01
# 471     michalewicz        200                  direct -5.114774e+01
# 625     michalewicz        200                  direct -5.114774e+01
# 201     michalewicz        200          dual_annealing -1.991910e+02
# 344     michalewicz        200          dual_annealing -1.991898e+02
# 568     michalewicz        200          dual_annealing -1.991743e+02
# 479     michalewicz        200          dual_annealing -1.991176e+02
# 269     michalewicz        200          dual_annealing -1.990358e+02
# 649     michalewicz        200                  gurobi -2.024635e+02
# 652     michalewicz        200                  gurobi -2.024635e+02
# 684     michalewicz        200                  gurobi -2.024635e+02
# 637     michalewicz        200                  gurobi -2.024635e+02
# 645     michalewicz        200                  gurobi -2.024635e+02
# 19      michalewicz        200                    mcir -1.773482e+02
# 472     michalewicz        200                    mcir -1.773482e+02
# 84      michalewicz        200                    mcir -1.772910e+02
# 540     michalewicz        200                    mcir -1.772910e+02
# 57      michalewicz        200                    mcir -1.759493e+02
# 197     michalewicz        200                    mcir -1.759493e+02
# 369     michalewicz        200                    mcir -1.713109e+02
# 454     michalewicz        200                    mcir -1.713109e+02
# 4       michalewicz        200                    mcir -1.709918e+02
# 129     michalewicz        200                    mcir -1.709918e+02
# 118     michalewicz        200                    shgo           inf
# 488     michalewicz        200                    shgo           inf
# 515     michalewicz        200                    shgo           inf
# 395     michalewicz        200                    shgo           inf
# 477     michalewicz        200                    shgo           inf
# 411     michalewicz        200     simulated_annealing -1.991564e+02
# 262     michalewicz        200     simulated_annealing -1.991325e+02
# 485     michalewicz        200     simulated_annealing -1.991067e+02
# 613     michalewicz        200     simulated_annealing -1.991055e+02
# 158     michalewicz        200     simulated_annealing -1.990565e+02
# 505       nn-ackley         50            basinhopping  2.096618e+01
# 0         nn-ackley         50            basinhopping  2.111772e+01
# 251       nn-ackley         50            basinhopping  2.120365e+01
# 159       nn-ackley         50            basinhopping  2.121697e+01
# 106       nn-ackley         50            basinhopping  2.124622e+01
# 431       nn-ackley         50  differential_evolution  2.099354e+01
# 109       nn-ackley         50  differential_evolution  2.100404e+01
# 202       nn-ackley         50  differential_evolution  2.102702e+01
# 398       nn-ackley         50  differential_evolution  2.103710e+01
# 401       nn-ackley         50  differential_evolution  2.103825e+01
# 22        nn-ackley         50                  direct  2.081027e+01
# 266       nn-ackley         50                  direct  2.081027e+01
# 574       nn-ackley         50                  direct  2.081027e+01
# 634       nn-ackley         50                  direct  2.081027e+01
# 61        nn-ackley         50                  direct  2.081027e+01
# 170       nn-ackley         50          dual_annealing  2.070288e+01
# 406       nn-ackley         50          dual_annealing  2.070291e+01
# 291       nn-ackley         50          dual_annealing  2.070323e+01
# 104       nn-ackley         50          dual_annealing  2.070441e+01
# 146       nn-ackley         50          dual_annealing  2.070511e+01
# 453       nn-ackley         50                    mcir  2.072482e+01
# 72        nn-ackley         50                    mcir  2.073122e+01
# 482       nn-ackley         50                    mcir  2.073471e+01
# 420       nn-ackley         50                    mcir  2.073499e+01
# 412       nn-ackley         50                    mcir  2.074990e+01
# 363       nn-ackley         50                    mcir  2.075233e+01
# 531       nn-ackley         50                    mcir  2.075283e+01
# 128       nn-ackley         50                    mcir  2.076191e+01
# 39        nn-ackley         50                    mcir  2.076647e+01
# 332       nn-ackley         50                    mcir  2.077190e+01
# 352       nn-ackley        100            basinhopping  2.119766e+01
# 186       nn-ackley        100            basinhopping  2.121140e+01
# 181       nn-ackley        100            basinhopping  2.123322e+01
# 338       nn-ackley        100            basinhopping  2.126048e+01
# 441       nn-ackley        100            basinhopping  2.128106e+01
# 490       nn-ackley        100  differential_evolution  2.113175e+01
# 564       nn-ackley        100  differential_evolution  2.114307e+01
# 461       nn-ackley        100  differential_evolution  2.114676e+01
# 580       nn-ackley        100  differential_evolution  2.114856e+01
# 537       nn-ackley        100  differential_evolution  2.115630e+01
# 111       nn-ackley        100                  direct  2.105489e+01
# 113       nn-ackley        100                  direct  2.105489e+01
# 593       nn-ackley        100                  direct  2.105489e+01
# 81        nn-ackley        100                  direct  2.105489e+01
# 285       nn-ackley        100                  direct  2.105489e+01
# 616       nn-ackley        100          dual_annealing  2.098319e+01
# 88        nn-ackley        100          dual_annealing  2.098395e+01
# 582       nn-ackley        100          dual_annealing  2.098438e+01
# 510       nn-ackley        100          dual_annealing  2.098466e+01
# 577       nn-ackley        100          dual_annealing  2.098614e+01
# 327       nn-ackley        100                    mcir  2.100234e+01
# 95        nn-ackley        100                    mcir  2.100570e+01
# 499       nn-ackley        100                    mcir  2.100903e+01
# 9         nn-ackley        100                    mcir  2.102436e+01
# 138       nn-ackley        100                    mcir  2.103959e+01
# 194  nn-michalewicz         50            basinhopping -9.553825e+01
# 175  nn-michalewicz         50            basinhopping -8.104476e+01
# 102  nn-michalewicz         50            basinhopping -7.688344e+01
# 238  nn-michalewicz         50            basinhopping -7.280955e+01
# 497  nn-michalewicz         50            basinhopping -6.782995e+01
# 295  nn-michalewicz         50  differential_evolution -9.056315e+00
# 484  nn-michalewicz         50  differential_evolution -7.777055e+00
# 622  nn-michalewicz         50  differential_evolution -7.759874e+00
# 114  nn-michalewicz         50  differential_evolution -7.746611e+00
# 56   nn-michalewicz         50  differential_evolution -6.899203e+00
# 243  nn-michalewicz         50                  direct -6.645740e+00
# 190  nn-michalewicz         50                  direct -6.645740e+00
# 142  nn-michalewicz         50                  direct -6.645740e+00
# 610  nn-michalewicz         50                  direct -6.645740e+00
# 246  nn-michalewicz         50                  direct -6.645740e+00
# 452  nn-michalewicz         50          dual_annealing -8.354682e+00
# 623  nn-michalewicz         50          dual_annealing -8.333874e+00
# 504  nn-michalewicz         50          dual_annealing -7.109344e+00
# 408  nn-michalewicz         50          dual_annealing -7.106549e+00
# 424  nn-michalewicz         50          dual_annealing -7.103039e+00
# 544  nn-michalewicz         50                    mcir -9.706660e+00
# 470  nn-michalewicz         50                    mcir -9.688899e+00
# 85   nn-michalewicz         50                    mcir -9.666862e+00
# 563  nn-michalewicz         50                    mcir -9.665192e+00
# 483  nn-michalewicz         50                    mcir -9.650689e+00
# 367  nn-michalewicz         50                    mcir -9.644274e+00
# 364  nn-michalewicz         50                    mcir -9.632134e+00
# 372  nn-michalewicz         50                    mcir -9.615363e+00
# 321  nn-michalewicz         50                    mcir -9.608938e+00
# 560  nn-michalewicz         50                    mcir -9.569359e+00
# 280  nn-michalewicz        100            basinhopping -1.300435e+02
# 66   nn-michalewicz        100            basinhopping -1.275441e+02
# 578  nn-michalewicz        100            basinhopping -1.124810e+02
# 458  nn-michalewicz        100            basinhopping -9.576870e+01
# 35   nn-michalewicz        100            basinhopping -9.200298e+01
# 153  nn-michalewicz        100  differential_evolution -1.510720e+01
# 529  nn-michalewicz        100  differential_evolution -1.236435e+01
# 150  nn-michalewicz        100  differential_evolution -1.226330e+01
# 552  nn-michalewicz        100  differential_evolution -1.226027e+01
# 428  nn-michalewicz        100  differential_evolution -1.224516e+01
# 166  nn-michalewicz        100                  direct -1.241530e+01
# 451  nn-michalewicz        100                  direct -1.241530e+01
# 605  nn-michalewicz        100                  direct -1.241530e+01
# 253  nn-michalewicz        100                  direct -1.241530e+01
# 163  nn-michalewicz        100                  direct -1.241530e+01
# 341  nn-michalewicz        100          dual_annealing -1.760905e+01
# 413  nn-michalewicz        100          dual_annealing -1.757715e+01
# 199  nn-michalewicz        100          dual_annealing -1.271467e+01
# 438  nn-michalewicz        100          dual_annealing -1.268016e+01
# 541  nn-michalewicz        100          dual_annealing -1.266320e+01
# 172  nn-michalewicz        100                    mcir -1.751221e+01
# 220  nn-michalewicz        100                    mcir -1.751169e+01
# 521  nn-michalewicz        100                    mcir -1.750841e+01
# 326  nn-michalewicz        100                    mcir -1.750522e+01
# 429  nn-michalewicz        100                    mcir -1.749352e+01
# 361          vardim        101                    mcir  9.262707e-05
# 255          watson         32            basinhopping  5.051535e-09
# 571          watson         32            basinhopping  8.438621e-09
# 573          watson         32            basinhopping  2.094683e-08
# 385          watson         32            basinhopping  3.903542e-08
# 200          watson         32            basinhopping  9.442822e-08
# 507          watson         32  differential_evolution  4.098551e-04
# ...
# 97     14.623480        100001               97688           False
# 480    22.863593        100001               99994           False
# 120    14.538188        100001               99992           False
# 225   501.933275       2802395                1700           False
# 350   563.981878       3288411                 528           False
# 63    580.943837       2790366              118257           False
# 31    527.878597       3157676              136854           False
# 632   418.475503       2831750              188569           False
# 167   431.159288       1502712             1502611           False
# 298   370.372750       1505540             1502197           False
# 457  1101.655168       1505843             1505742           False
# 390   483.126214       1502510             1502409           False
# 606  1129.590299       1502712             1502611           False
# 267    30.632854        105463              103813           False
# 335    35.135955        105463              103813           False
# 278    37.881288        105463              103813           False
# 444    38.757858        105463              103813           False
# 383    39.698909        105463              103813           False
# 305   257.478651        297062              296914           False
# 502   236.367119        289285              287526           False
# 132   174.857270        301304              300973           False
# 463   242.497902        303122              303020           False
# 619   234.261489        301708              300603           False
# 664    12.306810             1                   0            None
# 640    12.344491             1                   0            None
# 642    12.531595             1                   0            None
# 685    12.716558             1                   0            None
# 648    12.829502             1                   0            None
# 366    -1.000000        102170               92536            None
# 506    -1.000000        102170               92536            None
# 476    -1.000000        102098               94992            None
# 526    -1.000000        102098               94992            None
# 435    -1.000000        102133               97068            None
# 475    -1.000000        102133               97068            None
# 17     -1.000000        102177               98627            None
# 53     -1.000000        102177               98627            None
# 71     -1.000000        102166               98362            None
# 536    -1.000000        102166               98362            None
# 41    600.192289             0                   0            True
# 518   600.195540             0                   0            True
# 334   600.195826             0                   0            True
# 69    600.196474             0                   0            True
# 90    600.220402             0                   0            True
# 533    34.980337        200001              199903           False
# 239    33.675344        200001              199907           False
# 297    37.785274        200001              199920           False
# 149    39.283930        200001              199942           False
# 258    32.635686        200001              199200           False
# 206  6493.180060       3764566             1709620            True
# 626  6010.424139       2997530              905263            True
# 587  6753.828718       3008965              517242            True
# 358  7904.502558       3769184             2946138            True
# 236  6726.325541       3000377             2171335            True
# 237  1545.991869       3016467             3016266           False
# 486  2201.655338       3006618             3006417           False
# 232  1723.992732       3004809             3004608           False
# 136  1320.370509       3015864             3010369           False
# 312  2253.629135       3009633             3005354           False
# 427    21.818379        208669              205917           False
# 173    23.139295        208669              205917           False
# 25     33.014296        208669              205917           False
# 471    34.696766        208669              205917           False
# 625    37.518696        208669              205917           False
# 201   471.926382        768032              767693           False
# 344   471.600703        773660              773384           False
# 568   623.371556        756776              756427           False
# 479   468.098749        752555              752257           False
# 269   481.702665        785921              784767           False
# 649    25.935549             1                   0            None
# 652    26.003859             1                   0            None
# 684    26.289410             1                   0            None
# 637    26.292961             1                   0            None
# 645    26.728748             1                   0            None
# 19     -1.000000        153038              151515            None
# 472    -1.000000        153038              151515            None
# 84     -1.000000        153065              152811            None
# 540    -1.000000        153065              152811            None
# 57     -1.000000        153053              153052            None
# 197    -1.000000        153053              153052            None
# 369    -1.000000        152942              150907            None
# 454    -1.000000        152942              150907            None
# 4      -1.000000        153063              151287            None
# 129    -1.000000        153063              151287            None
# 118   600.163565             0                   0            True
# 488   600.186176             0                   0            True
# 515   600.189185             0                   0            True
# 395   600.189831             0                   0            True
# 477   600.192884             0                   0            True
# 411   135.053649        400001              399599           False
# 262    80.138950        400001              399955           False
# 485   134.001523        400001              399957           False
# 613   152.514497        400001              399066           False
# 158    84.547086        400001              399842           False
# 505    83.513190         51663               44217           False
# 0     108.239230         56595               17544           False
# 251    86.137089         53091               13974           False
# 159    85.170391         51051                2448           False
# 106    88.568939         54339               11016           False
# 431     2.569880          1551                1072           False
# 109     2.895055          1551                1399           False
# 202     3.396306          1551                1457           False
# 398     3.178841          1551                1189           False
# 401     4.058889          1551                 166           False
# 22     53.822276         36421               36401           False
# 266    54.852530         36421               36401           False
# 574    57.696809         36421               36401           False
# 634    57.807289         36421               36401           False
# 61     58.368842         36421               36401           False
# 170   197.591341        110150              109683           False
# 406   201.127552        111833              110643           False
# 291   194.659590        110303              110247           False
# 104   196.423967        109181              107619           False
# 146   198.378612        109844              106647           False
# 453    -1.000000         25982               24184            None
# 72     -1.000000         51723               20074            None
# 482    -1.000000         51698               46821            None
# 420    -1.000000         25968                 257            None
# 412    -1.000000         51644               33387            None
# 363    -1.000000         51697                8496            None
# 531    -1.000000         25983                1291            None
# 128    -1.000000         51648               23904            None
# 39     -1.000000         26022                6179            None
# 332    -1.000000         25983               25725            None
# 352   177.752511        105254               55663           False
# 186   161.610483        101101               23634           False
# 181   167.068446        101101               21210           False
# 338   171.948519        101101               40198           False
# 441   159.695177        101101               13534           False
# 490     6.638501          3101                1752           False
# 564     5.551451          3101                2100           False
# 461     5.589668          3101                2312           False
# 580     7.528274          3101                1968           False
# 537     6.479701          3101                 485           False
# 111   114.858944         76255               72091           False
# 113   119.711217         76255               72091           False
# 593   122.356518         76255               72091           False
# 81    123.821192         76255               72091           False
# 285   136.408109         76255               72091           False
# 616   393.237756        223029              221080           False
# 88    391.974973        223231              223102           False
# 582   367.912436        222019              216060           False
# 510   423.707139        217474              212946           False
# 577   391.719680        219898              219752           False
# 327    -1.000000        225525              158206            None
# 95     -1.000000        225477               99890            None
# 499    -1.000000        225500              173800            None
# 9      -1.000000        225689              159298            None
# 138    -1.000000        225233              187112            None
# 194   171.434055        100890              100686           False
# 175   177.810059        111444              111393           False
# 102   151.058573         92325               92274           False
# 238   200.564448        123730              120607           False
# 497   249.776005        145947              145080           False
# 295   385.324947        204801              186914           False
# 484   165.918538         84051               78309           False
# 622   118.939909         60801               58046           False
# 114   115.438799         60801               59032           False
# 56     30.014918         16551               13976           False
# 243     1.869633          1147                 771           False
# 190     1.987142          1147                 771           False
# 142     2.114840          1147                 771           False
# 610     2.367488          1147                 771           False
# 246     2.700269          1147                 771           False
# 452   256.497736        145289              145121           False
# 623   216.735130        145544              145259           False
# 504   204.534649        117749              115760           False
# 408   238.999881        122594              120540           False
# 424   219.894065        123002              120713           False
# 544    -1.000000         52817               40985            None
# 470    -1.000000         52910               46563            None
# 85     -1.000000         52890               44762            None
# 563    -1.000000         26572               19490            None
# 483    -1.000000         52893               43951            None
# 367    -1.000000         52975                4238            None
# 364    -1.000000         26521               22836            None
# 372    -1.000000         26585                1833            None
# 321    -1.000000         26597                9518            None
# 560    -1.000000         26518               18078            None
# 280   386.217117        217413              217312           False
# 66    395.154221        236145              236044           False
# 578   457.668870        277487              277386           False
# 458   495.227301        287864              287662           False
# 35    321.442395        252355              252153           False
# 153   577.065319        292601              231887           False
# 529    36.625003         18101               15410           False
# 150    45.706431         21101               13898           False
# 552    41.243821         21101               13163           False
# 428    42.032271         21101               15454           False
# 166     5.214435          3497                2391           False
# 451     5.363364          3497                2391           False
# 605     5.484943          3497                2391           False
# 253     6.077899          3497                2391           False
# 163     6.610231          3497                2391           False
# 341   478.368307        277973              277656           False
# 413   392.187075        307061              306869           False
# 199   427.802829        246057              240723           False
# 438   448.310675        251915              251189           False
# 541   431.788532        239795              232206           False
# 172    -1.000000        229524               34144            None
# 220    -1.000000        229791               52587            None
# 521    -1.000000        229649              228468            None
# 326    -1.000000        229765               54708            None
# 429    -1.000000        229672              138263            None
# 361    -1.000000        105451               85109            None
# 255  3617.150820       1694451              389201            True
# 571  3617.247036       1782043                8054            True
# 573  3618.283260       1686729             1519451            True
# 385  3602.725276       1607982             1215998            True
# 200  3603.018095       1539968              357887            True
# 507   227.136599        491238              491207           False
# 589   220.801278        495495              495494           False
# 78    293.553789        491898              491871           False
# 94    231.272146        487674              487643           False
# 131   168.813669        495495              495464           False
# 67      1.378877          3085                1849           False
# 434     1.485945          3085                1849           False
# 633     1.515078          3085                1849           False
# 214     1.578418          3085                1849           False
# 8       1.582426          3085                1849           False
# 196    35.830351         71525                7558           False
# 612    23.355160         71723                7757           False
# 110    37.428875         71756                7789           False
# 631    35.577699         71624                7687           False
# 293    35.039673         71492                7536           False
# 221    -1.000000        218640              214287            None
# 328    -1.000000        218074               32283            None
# 54   3601.669902             0                   0            True
# 288  3601.854003             0                   0            True
# 148  3601.968753             0                   0            True
# 559  3601.974911             0                   0            True
# 222  3602.063887             0                   0            True
